# %%
# Render our plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1 Reading data from a csv file

# %% [markdown]
# You can read data from a CSV file using the `read_csv` function. By default, it assumes that the fields are comma-separated.
#
# We're going to be looking some cyclist data from Montréal. Here's the [original page](http://donnees.ville.montreal.qc.ca/dataset/velos-comptage) (in French). You can find this dataset on Moodle.
#
# This dataset is a list of how many people were on 7 different bike paths in Montreal, each day.
#
# It's easy to read a CSV using Pandas. To make sure the plots we are going to make later work correctly, we need to specify that the *index* of this data-frame is the 'Date'. We also need to tell Pandas that the column 'date' contains dates.

# %%
df = pd.read_csv('bikes.csv', parse_dates=['Date'],  index_col='Date')

# %% [markdown]
# You can look at the first rows using **head**.

# %%
df.head()
# Out:
#            Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# Date
# 2012-01-01      00:00                 16      35             51
# 2012-02-01      00:00                 43      83            153
# 2012-03-01      00:00                 58     135            248
# 2012-04-01      00:00                 61     144            318
# 2012-05-01      00:00                 95     197            330
#
#             Maisonneuve_1  Brébeuf  Parc  PierDup  \
# Date
# 2012-01-01             38      5.0    26       10
# 2012-02-01             68     11.0    53        6
# 2012-03-01            104      2.0    89        3
# 2012-04-01            116      2.0   111        8
# 2012-05-01            124      6.0    97       13
#
#             CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# Date
# 2012-01-01                            0                  27.0
# 2012-02-01                            1                  21.0
# 2012-03-01                            2                  15.0
# ...

# %% [markdown]
# And the last rows using **tail**

# %%
df.tail()
# Out:
#            Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# Date
# 2012-12-27      00:00                  8      12              7
# 2012-12-28      00:00                  0      35              3
# 2012-12-29      00:00                  0      27              8
# 2012-12-30      00:00                  0       5              1
# 2012-12-31      00:00                  0       4              3
#
#             Maisonneuve_1  Brébeuf  Parc  PierDup  \
# Date
# 2012-12-27              4      NaN     1        2
# 2012-12-28             38      NaN     0        0
# 2012-12-29             42      NaN     9        0
# 2012-12-30              5      NaN     6        0
# 2012-12-31              8      NaN    12        0
#
#             CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# Date
# 2012-12-27                            0                   NaN
# 2012-12-28                            0                   NaN
# 2012-12-29                            0                   NaN
# ...

# %% [markdown]
# # 1.2 Selecting a column

# %% [markdown]
# When you read a CSV, you get a kind of object called a `DataFrame`, which is made up of rows and columns. You get columns out of a DataFrame the same way you get elements out of a dictionary.
#
# Here's an example:

# %%
df['Berri1']
# Out:
# Date
# 2012-01-01      35
# 2012-02-01      83
# 2012-03-01     135
# 2012-04-01     144
# 2012-05-01     197
# 2012-06-01     146
# 2012-07-01      98
# 2012-08-01      95
# 2012-09-01     244
# 2012-10-01     397
# 2012-11-01     273
# 2012-12-01     157
# 2012-01-13      75
# 2012-01-14      32
# 2012-01-15      54
# 2012-01-16     168
# 2012-01-17     155
# 2012-01-18     139
# 2012-01-19     191
# 2012-01-20     161
# 2012-01-21      53
# 2012-01-22      71
# 2012-01-23     210
# 2012-01-24     299
# 2012-01-25     334
# 2012-01-26     306
# 2012-01-27      91
# 2012-01-28      80
# 2012-01-29      87
# 2012-01-30     219
#               ...
# 2012-02-12     324
# 2012-03-12    1286
# 2012-04-12    1264
# 2012-05-12    1204
# 2012-06-12    1252
# 2012-07-12    1151
# 2012-08-12     382
# 2012-09-12     427
# 2012-10-12     245
# 2012-11-12     517
# 2012-12-12     598
# 2012-12-13     655
# 2012-12-14     738
# 2012-12-15     335
# 2012-12-16     177
# 2012-12-17     236
# ...

# %% [markdown]
# # 1.3 Plotting a column

# %% [markdown]
# Just add `.plot()` to the end! How could it be easier? =)
#
# We can see that, unsurprisingly, not many people are biking in January, February, and March,

# %%
df['Berri1'].plot()

# %% [markdown]
# We can also plot all the columns just as easily. We'll make it a little bigger, too.
# You can see that it's more squished together, but all the bike paths behave basically the same -- if it's a bad day for cyclists, it's a bad day everywhere.

# %%
df.plot(figsize=(15, 10))

# %% [markdown]
# # 1.4 Putting all that together

# %% [markdown]
# Here's the code we needed to write do draw that graph, all together:

# %%
df = pd.read_csv('bikes.csv', parse_dates=['Date'],  index_col='Date')['Berri1'].plot()

# %% [markdown]
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 22pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
