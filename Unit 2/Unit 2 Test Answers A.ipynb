# %%
import pandas as pd
import numpy as np

df = pd.read_csv('training_ratings_for_kaggle_comp.csv')

# %%
# A1: Return all movies with rating = 5.
df[df['rating'] == 5]
# Out:
#         user  movie  rating         id
# 0       2783   1253       5  2783_1253
# 1       2783    589       5   2783_589
# 4       2783    741       5   2783_741
# 5       2783    750       5   2783_750
# 6       2783    924       5   2783_924
# 16      2783   1301       5  2783_1301
# 24      2783   3175       5  2783_3175
# 27      2783   1584       5  2783_1584
# 28      2783   1748       5  2783_1748
# 29      2783   2553       5  2783_2553
# 30      2783   2571       5  2783_2571
# 31      2783   3527       5  2783_3527
# 32      2783   1019       5  2783_1019
# 34      2783   1965       5  2783_1965
# 36      2783   3576       5  2783_3576
# 37      2783    527       5   2783_527
# 42      2783   1077       5  2783_1077
# 43      2783   2968       5  2783_2968
# 54      2784   3173       5  2784_3173
# 60      2784   1060       5  2784_1060
# 112     2785   2669       5  2785_2669
# 183     2785   1784       5  2785_1784
# 193     2785   1959       5  2785_1959
# ...

# %%
# A2: Find the average movie ratings that user 2783 gave.
user_2783 = df[df['user'] == 2783]
np.mean(df['rating'])
# Out:
# 3.6022235552889423

# %%
# A3: How many unique movies are there?
len(df['movie'].unique())
# Out:
# 3551

# %%
# A4: Print all movie ids with rating > 4. 
df[df['rating'] > 4]
# Out:
#         user  movie  rating         id
# 0       2783   1253       5  2783_1253
# 1       2783    589       5   2783_589
# 4       2783    741       5   2783_741
# 5       2783    750       5   2783_750
# 6       2783    924       5   2783_924
# 16      2783   1301       5  2783_1301
# 24      2783   3175       5  2783_3175
# 27      2783   1584       5  2783_1584
# 28      2783   1748       5  2783_1748
# 29      2783   2553       5  2783_2553
# 30      2783   2571       5  2783_2571
# 31      2783   3527       5  2783_3527
# 32      2783   1019       5  2783_1019
# 34      2783   1965       5  2783_1965
# 36      2783   3576       5  2783_3576
# 37      2783    527       5   2783_527
# 42      2783   1077       5  2783_1077
# 43      2783   2968       5  2783_2968
# 54      2784   3173       5  2784_3173
# 60      2784   1060       5  2784_1060
# 112     2785   2669       5  2785_2669
# 183     2785   1784       5  2785_1784
# 193     2785   1959       5  2785_1959
# ...

# %%
# A5: Print all movie ids with ratings between 2 and 3.
df[(df['rating'] >= 2) & (df['rating'] <= 3)]
# Out:
#         user  movie  rating         id
# 8       2783   3070       3  2783_3070
# 11      2783   2640       2  2783_2640
# 12      2783   3471       3  2783_3471
# 15      2783    610       3   2783_610
# 17      2783   2111       3  2783_2111
# 19      2783   1199       3  2783_1199
# 21      2783   1356       2  2783_1356
# 23      2783   1376       3  2783_1376
# 26      2783   1580       2  2783_1580
# 33      2783   3702       3  2783_3702
# 35      2783     32       3    2783_32
# 39      2783   1210       3  2783_1210
# 44      2783   1097       3  2783_1097
# 45      2783   3927       3  2783_3927
# 46      2783   1243       3  2783_1243
# 48      2784   3452       3  2784_3452
# 50      2784    464       3   2784_464
# 51      2784   3101       3  2784_3101
# 52      2784   1396       3  2784_1396
# 55      2784   3534       3  2784_3534
# 56      2784   3535       3  2784_3535
# 57      2784   1942       3  2784_1942
# 63      2785    586       3   2785_586
# ...

# %%
# A6: Calculate the average rating of each movie.
df.groupby('movie')['rating'].agg(np.mean)
# Out:
# movie
# 1       4.146630
# 2       3.230769
# 3       2.977401
# 4       2.770833
# 5       2.960526
# 6       3.968566
# 7       3.421525
# 8       3.100000
# 9       2.673469
# 10      3.537797
# 11      3.807615
# 12      2.333333
# 13      3.380000
# 14      3.424242
# 15      2.661765
# 16      3.832370
# 17      4.045783
# 18      3.657895
# 19      2.554404
# 20      2.607595
# 21      3.648536
# 22      3.425121
# 23      2.944444
# 24      3.235849
# 25      3.662857
# 26      3.600000
# 27      2.906250
# 28      4.098901
# 29      4.091743
# 30      3.700000
#           ...
# 3919    2.470588
# 3920    4.000000
# 3921    2.428571
# 3922    2.500000
# 3923    2.700000
# 3924    2.000000
# 3925    4.100000
# 3926    3.423077
# 3927    3.759259
# 3928    3.370370
# 3929    4.200000
# 3930    3.333333
# 3931    3.000000
# 3932    3.916667
# 3933    4.000000
# 3934    3.333333
# 3935    3.000000
# 3936    3.785714
# 3937    2.928571
# 3938    1.000000
# 3939    1.000000
# ...
