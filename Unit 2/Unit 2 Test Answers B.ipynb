# %%
import pandas as pd
import numpy as np

# %%
# 1. Import the dog bites dataset
df = pd.read_csv('dog_bites.csv')

# %%
#2. Check that every row has the species 'DOG'
df['Species'].unique()
# Out:
# array(['DOG'], dtype=object)

# %%
#3. Convert all breeds to lower case
df['Breed'] = df['Breed'].str.lower()

# %%
# 4. Find the number of dogs of each gender
df['Gender'].value_counts()
# Out:
# M    4121
# U    2978
# F    1608
# Name: Gender, dtype: int64

# %%
# 5. Make a plot showing how many dogs were of the 10 most common breeds.
df['Breed'].value_counts()[:10].plot(kind = 'bar')
