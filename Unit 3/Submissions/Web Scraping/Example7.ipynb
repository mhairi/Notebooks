# %%
#WEB SCRAPING ACTIVY TASK STARTS FURTHER IN THE NOTEBOOK. THESE ARE THE INITIAL TASKS. 

import json as json
from pprint import pprint

# %%
with open('starwars.json', 'r') as data_file:
    data = json.load(data_file)

# %%
pprint(data)
# Out:
# {'count': 87,
#  'next': 'https://swapi.co/api/people/?page=2',
#  'previous': None,
#  'results': [{'birth_year': '19BBY',
#               'created': '2014-12-09T13:50:51.644000Z',
#               'edited': '2014-12-20T21:17:56.891000Z',
#               'eye_color': 'blue',
#               'films': ['https://swapi.co/api/films/2/',
#                         'https://swapi.co/api/films/6/',
#                         'https://swapi.co/api/films/3/',
#                         'https://swapi.co/api/films/1/',
#                         'https://swapi.co/api/films/7/'],
#               'gender': 'male',
#               'hair_color': 'blond',
#               'height': '172',
#               'homeworld': 'https://swapi.co/api/planets/1/',
#               'mass': '77',
#               'name': 'Luke Skywalker',
#               'skin_color': 'fair',
#               'species': ['https://swapi.co/api/species/1/'],
#               'starships': ['https://swapi.co/api/starships/12/',
# ...

# %%
data
# Out:
# {'count': 87,
#  'next': 'https://swapi.co/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.co/api/planets/1/',
#    'films': ['https://swapi.co/api/films/2/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/',
#     'https://swapi.co/api/films/1/',
#     'https://swapi.co/api/films/7/'],
#    'species': ['https://swapi.co/api/species/1/'],
#    'vehicles': ['https://swapi.co/api/vehicles/14/',
#     'https://swapi.co/api/vehicles/30/'],
#    'starships': ['https://swapi.co/api/starships/12/',
#     'https://swapi.co/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.co/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
# ...

# %%
#C-3PO birth year

pprint(data['results'][1]['birth_year'])
# Out:
# '112BBY'

# %%
from bs4 import BeautifulSoup
import requests
import csv
from datetime import datetime

# %%
url = 'https://www.newlook.com/uk/womens/clothing/dresses/black-floral-print-soft-touch-skater-dress/p/563723709?comp=Browse'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
product_name = soup.find('h1', attrs={'class':'product-description__name'})

# %%
name = product_name.text.strip()

# %%
name
# Out:
# 'Black Floral Print Soft Touch Skater Dress'

# %%
#Example. I cannot webscrape a sales item, even though the tag and class shows in the html code "soup2"

url2 = 'https://www.newlook.com/uk/womens/clothing/dresses/black-floral-print-soft-touch-skater-dress/p/563723709?comp=Browse'
page2 = requests.get(url2)
soup2 = BeautifulSoup(page2.content, 'html.parser')
product_price = soup.find('span', attrs={'class' : 'price price--marked-down product-description__price'})
#price = product_price.text.strip()
soup2
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en" ng-app="newlookApp" ng-strict-di="">
# <head>
# <!-- CID: 4 -->
# <title>
# 		Black Floral Print Soft Touch Skater Dress | New Look</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1, user-scalable=no" name="viewport">
# <meta name="keywords"/>
# <meta content="Shop Black Floral Print Soft Touch Skater Dress. Discover the latest trends at New Look." name="description"/>
# <meta content="index,archive,follow" name="robots"/>
# <link href="https://www.newlook.com/uk/womens/clothing/dresses/black-floral-print-soft-touch-skater-dress/p/563723709" rel="canonical"/>
# ...

# %%
#WEB SCRAPING ACTIVITY TASK STARTS HERE

url = ['https://www.newlook.com/uk/mens/view-all-footwear/shoes/black-embossed-shoes/p/590246101?comp=Browse', 
       'https://www.newlook.com/uk/mens/view-all-footwear/shoes/dark-brown-chunky-sole-brogues-/p/611068927?comp=Browse', 
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/black-panelled-lightweight-chunky-trainers/p/607759501?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/white-panelled-lightweight-chunky-trainers/p/607759510?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/black-leather-look-and-suedette-tassel-loafers/p/607779201?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/brown-leather-look-and-suedette-tassel-loafers/p/607779227?comp=Browse',
      'https://www.newlook.com/uk/womens/footwear/boots/tan-faux-suede-chelsea-boots-/p/607833118?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/black-leather-look-fringe-tassel-loafers/p/607864901?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/dark-brown-fringe-tassel-loafers/p/607864927?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/stone-suedette-bar-front-loafers/p/607927616?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/dark-brown-suedette-bar-front-loafers/p/607927627?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/navy-suedette-bar-front-loafers/p/607927641?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/black-suedette-lace-up-derby-shoes/p/607928701?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/stone-suedette-lace-up-derby-shoes/p/607928716?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/dark-brown-suedette-lace-up-derby-shoes/p/607928727?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/navy-suedette-lace-up-derby-shoes/p/607928741?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/dark-brown-embossed-shoes/p/590246127?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/black-tassel-trim-loafers-/p/595707601?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/black-leather-look-lace-up-formal-shoes/p/569205901?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/dark-brown-leather-look-lace-up-formal-shoes/p/569205927?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/black-geometric-textured-zip-side-trainers/p/613207301?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/tan-perforated-lace-up-brogues/p/574665018?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/white-side-stripe-perforated-trainers/p/595334410?comp=Browse',
      'https://www.newlook.com/uk/mens/view-all-footwear/shoes/black-perforated-lace-up-gibson-shoes/p/566085101?comp=Browse']

data = []

for pg in url:
    page = requests.get(pg)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    product_name = soup.find('h1', attrs={'class':'product-description__name'})
    product_price = soup.find('span', attrs={'class' : 'price product-description__price'})
    
    price = product_price.text.strip()
    name = product_name.text.strip()
    
    data.append((name, price))
    
with open('results.csv', 'a') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(["Name","Price","Date"])
    for name, price in data:
        writer.writerow([name,price,datetime.now()])

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('results.csv', parse_dates=['Date'], index_col='Date', encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#                                                                       Name  \
# Date
# 2019-02-02 13:31:00.183583                            Black Embossed Shoes
# 2019-02-02 13:31:00.183583                  Dark Brown Chunky Sole Brogues
# 2019-02-02 13:31:00.183583      Black Panelled Lightweight Chunky Trainers
# 2019-02-02 13:31:00.183583      White Panelled Lightweight Chunky Trainers
# 2019-02-02 13:31:00.183583  Black Leather-Look and Suedette Tassel Loafers
#
#                              Price
# Date
# 2019-02-02 13:31:00.183583  £29.99
# 2019-02-02 13:31:00.183583  £32.99
# 2019-02-02 13:31:00.183583  £24.99
# 2019-02-02 13:31:00.183583  £24.99
# 2019-02-02 13:31:00.183583  £29.99

# %%
#Remove currency symbol

df['Price'] = df.Price.str.replace('£', '')

# %%
#Convert from object to float, so that I can calculate average cost.

df.Price = df.Price.astype(float)

# %%
average_price = df.Price.mean()

# %%
average_price
# Out:
# 27.490000000000006

# %%
most_expensive = df.sort_values(by='Price', ascending=False).head()

# %%
most_expensive
# Out:
#                                                                 Name  Price
# Date
# 2019-02-02 13:31:00.183583  Black Leather-Look Fringe Tassel Loafers  32.99
# 2019-02-02 13:31:00.183583          Dark Brown Fringe Tassel Loafers  32.99
# 2019-02-02 13:31:00.183583            Dark Brown Chunky Sole Brogues  32.99
# 2019-02-02 13:31:00.183583                      Black Embossed Shoes  29.99
# 2019-02-02 13:31:00.183583                 Black Tassel Trim Loafers  29.99

# %%
cheapest = df.sort_values(by='Price', ascending=True).head()

# %%
cheapest
# Out:
#                                                                     Name  \
# Date
# 2019-02-02 13:31:00.183583  Dark Brown Leather-Look Lace-Up Formal Shoes
# 2019-02-02 13:31:00.183583       Black Leather-Look Lace Up Formal Shoes
# 2019-02-02 13:31:00.183583         White Side Stripe Perforated Trainers
# 2019-02-02 13:31:00.183583         Black Perforated Lace-Up Gibson Shoes
# 2019-02-02 13:31:00.183583                Tan Perforated Lace Up Brogues
#
#                             Price
# Date
# 2019-02-02 13:31:00.183583  19.99
# 2019-02-02 13:31:00.183583  19.99
# 2019-02-02 13:31:00.183583  19.99
# 2019-02-02 13:31:00.183583  22.99
# 2019-02-02 13:31:00.183583  22.99
